# %% [markdown]
# # 🐍 Beginner-Friendly Python Tutorial with Explanations
# Welcome to your first Python tutorial! This notebook takes you from the basics of Python to a simple machine learning example using Scikit-learn.
#
# ---
#
# **👩‍🏫 What you'll learn:**
# - Basic syntax: `print`, variables, data types
# - Control structures: conditionals, loops
# - Functions: defining and calling
# - Machine learning: using `scikit-learn` to classify flowers
#
# Let's get started! 🚀

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## 🧾 Section 1: Getting Started with Python

# %% [markdown]
# ### 🔹 Print Statement
# The `print()` function is used to display output on the screen.

# %%
print("Hello, Chemoinformatics World!")
# Out:
# Hello, Chemoinformatics World!

# %% [markdown]
# ### 🔹 Variables and Data Types
# Variables are used to store data. Python supports several built-in data types:
# - `int`: Integer numbers like 1, 2, 10
# - `float`: Decimal numbers like 3.14, 2.5
# - `str`: Text or string values like "hello"
# - `bool`: Boolean values `True` or `False`
#
# You can create variables and assign values using the `=` operator.

# %%
smiles = "CCO"
molecular_weight = 25.23
hdb = 5
is_smile = True

print("SMILES:", smiles)
print("MW:", molecular_weight)
print("HBD:", hdb)
print("Valid:", is_smile)
# Out:
# SMILES: CCO
# MW: 25.23
# HBD: 5
# Valid: True

# %% [markdown]
# ### 🔹 Lists
# Lists are used to store multiple items in a single variable. They are ordered and changeable.
# They are:
#
# ✅ Ordered – items have a defined order and that order will not change unless you do it explicitly.
#
# ✅ Mutable (changeable) – you can modify, add, or remove elements after the list has been created.
#
# ✅ Can contain mixed data types – like strings, integers, floats, or even other lists.

# %%
fruits = ["apple", "banana", "cherry"]
print("Fruits:", fruits)
print("First fruit:", fruits[0])
# Out:
# Fruits: ['apple', 'banana', 'cherry']
# First fruit: apple

# %%
smiles_list = [
    "CCO",                      # Ethanol
    "CC(=O)OC1=CC=CC=C1C(=O)O", # Aspirin
    "C1=CC=CC=C1"               # Benzene
]

print("SMILES list:", smiles_list)
print("First molecule SMILES:", smiles_list[0])
# Out:
# SMILES list: ['CCO', 'CC(=O)OC1=CC=CC=C1C(=O)O', 'C1=CC=CC=C1']
# First molecule SMILES: CCO

# %% [markdown]
# ### 🔹 Loops
# Loops are used to execute a block of code repeatedly. Use a `for` loop to iterate over lists.
#
# 🔸 for Loop
# 🔹Used when you know how many times you want to loop.
#
# 🔹Often used to iterate over sequences like lists, tuples, strings, or ranges.

# %%
for fruit in fruits:
    print("I like", fruit)
# Out:
# I like apple
# I like banana
# I like cherry

# %%
for smiles in smiles_list:
    print(smiles)
# Out:
# CCO
# CC(=O)OC1=CC=CC=C1C(=O)O
# C1=CC=CC=C1

# %% [markdown]
# # --- 🔬 Installing RDKit ---
#
# RDKit is a powerful open-source toolkit for **cheminformatics** and **computational chemistry**.
# It helps in handling molecular structures, SMILES strings, SDF files, molecular fingerprints, descriptors, and more.
#
# ---
#
# ### 🔹 Installation in Google Colab
#
# In Google Colab, you can install RDKit using:
#
# ```python
# !pip install rdkit -q

# %%
# !pip install rdkit -q

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# %%
for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    if mol:  # Check if conversion was successful
        display(Draw.MolToImage(mol))
    else:
        print(f"Could not parse SMILES: {smiles}")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# # --- 📌 While Loop ---
# A while loop repeats a block of code while a condition is True.
#
# 🔸 while Loop
#
# Used when you don't know exactly how many times to loop.
#
# It continues as long as a condition is True.

# %%
count = 0
while count < 3:
    print("Count is:", count)
    count += 1
# Out:
# Count is: 0
# Count is: 1
# Count is: 2

# %%
index = 0
while index < len(smiles_list):
    print(smiles_list[index])
    index += 1
# Out:
# CCO
# CC(=O)OC1=CC=CC=C1C(=O)O
# C1=CC=CC=C1

# %% [markdown]
# ### --- 📌 Tuple ---
#
# A **tuple** is a collection that is **ordered** and **immutable** (cannot be changed after creation).
# Tuples are similar to lists but use **parentheses `()`** instead of square brackets.
#
# ---
#
# #### 🔹 Key Features:
# - ✅ Immutable: You can't change, add, or remove elements
# - ✅ Ordered: Elements maintain their order
# - ✅ Can contain mixed data types
# - ✅ Faster than lists
# - ✅ Can be used as keys in dictionaries
#
# ---

# %%
my_tuple = (1, 2, 3)
print("Tuple:", my_tuple)
print("Second item:", my_tuple[1])
# Out:
# Tuple: (1, 2, 3)
# Second item: 2

# %% [markdown]
# ### --- 📌 Dictionary ---
#
# A **dictionary** in Python is used to store **data in key:value pairs**.
# It is **unordered**, **mutable**, and does **not allow duplicate keys**.
#
# ---
#
# #### 🔹 Key Features:
# - ✅ Uses `{}` curly braces
# - ✅ Keys must be unique and immutable (like strings, numbers, or tuples)
# - ✅ Values can be any type: string, list, number, even another dictionary!
# - ✅ Fast lookup by keys
#
# ---

# %%
person = {"name": "Alice", "age": 25, "city": "New York"}
print("Person's name:", person["name"])
print("Full dictionary:", person)
# Out:
# Person's name: Alice
# Full dictionary: {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %%
molecules = {
    "aspirin": "CC(=O)OC1=CC=CC=C1C(=O)O",
    "ethanol": "CCO",
    "benzene": "C1=CC=CC=C1"
}

print("Aspirin SMILES:", molecules["aspirin"])
# Out:
# Aspirin SMILES: CC(=O)OC1=CC=CC=C1C(=O)O

# %% [markdown]
# ### 🔹 Conditionals in Python
#
# Conditional statements allow a program to execute certain blocks of code based on whether a condition is `True` or `False`.
#
# ---
#
# #### 🔹 Keywords Used:
# - `if`: Executes a block of code if the condition is true.
# - `elif`: Stands for "else if", checks another condition if the previous one was false.
# - `else`: Executes a block of code if none of the above conditions are true.
#
# ---

# %%
mol_wt = 1400
if mol_wt > 500:
    print("Molecular weight is too high.")
elif mol_wt < 100:
    print("Molecular weight is too low")
else:
    print("Molecular weight in medium range")
# Out:
# Molecular weight is too high.

# %% [markdown]
# # --- 📌 Nested Conditions ---
# You can nest if statements inside each other.

# %%
x = 10
y = 20
if x < y:
    if y < 30:
        print("x is less than y and y is less than 30")
# Out:
# x is less than y and y is less than 30

# %% [markdown]
# # --- 📌 Operators in Python ---
#
# Operators are special symbols in Python used to perform operations on variables and values.
#
# ---
#
# ### 🔹 1. Arithmetic Operators
# Used to perform basic mathematical operations:
#
# | Operator | Description      | Example    | Output |
# |----------|------------------|------------|--------|
# | `+`      | Addition          | `3 + 2`    | `5`    |
# | `-`      | Subtraction       | `3 - 2`    | `1`    |
# | `*`      | Multiplication    | `3 * 2`    | `6`    |
# | `/`      | Division          | `3 / 2`    | `1.5`  |
# | `//`     | Floor Division    | `3 // 2`   | `1`    |
# | `%`      | Modulus (remainder)| `3 % 2`   | `1`    |
# | `**`     | Exponentiation    | `3 ** 2`   | `9`    |
#
# ---
#
# ### 🔹 2. Comparison (Relational) Operators
# Used to compare two values and return `True` or `False`:
#
# | Operator | Description     | Example     | Output   |
# |----------|------------------|-------------|----------|
# | `==`     | Equal to          | `3 == 2`    | `False`  |
# | `!=`     | Not equal to      | `3 != 2`    | `True`   |
# | `>`      | Greater than      | `3 > 2`     | `True`   |
# | `<`      | Less than         | `3 < 2`     | `False`  |
# | `>=`     | Greater or equal  | `3 >= 2`    | `True`   |
# | `<=`     | Less or equal     | `3 <= 2`    | `False`  |
#
# ---
#
# ### 🔹 3. Logical Operators
# Used to combine conditional statements:
#
# | Operator | Description               | Example                 | Output   |
# |----------|----------------------------|--------------------------|----------|
# | `and`    | True if both are True      | `True and False`         | `False`  |
# | `or`     | True if one is True        | `True or False`          | `True`   |
# | `not`    | Reverse the result         | `not(True)`              | `False`  |
#
# ---
#
# ### 🔹 4. Assignment Operators
# Used to assign values to variables:
#
# | Operator | Example  | Equivalent To   |
# |----------|----------|-----------------|
# | `=`      | `x = 5`  | Assigns 5 to x  |
# | `+=`     | `x += 2` | `x = x + 2`     |
# | `-=`     | `x -= 1` | `x = x - 1`     |
# | `*=`     | `x *= 3` | `x = x * 3`     |
# | `/=`     | `x /= 2` | `x = x / 2`     |
# | `//=`    | `x //= 2`| `x = x // 2`    |
# | `%=`     | `x %= 2` | `x = x % 2`     |
# | `**=`    | `x **= 2`| `x = x ** 2`    |
#
# ---
#
# ### 🔹 5. Membership Operators
# Check whether a value is in a sequence (like a list, tuple, string, etc.):
#
# | Operator | Description               | Example         | Output   |
# |----------|----------------------------|------------------|----------|
# | `in`     | True if found in sequence  | `'a' in 'cat'`   | `True`   |
# | `not in` | True if not found          | `'x' not in 'cat'`| `True`  |
#
# ---
#
# ### 🔹 6. Identity Operators
# Check whether two variables refer to the same object:
#
# | Operator | Description            | Example      | Output   |
# |----------|------------------------|--------------|----------|
# | `is`     | Same object             | `x is y`     | `True/False` |
# | `is not` | Not same object         | `x is not y` | `True/False` |
#
# ---
#
# ✅ **Summary**:
# Operators help you manipulate data and build logic in your code. Mastering them is essential for writing clean and powerful Python programs.

# %%
a = 5
b = 2

# Arithmetic Operators
print("Addition:", a + b)
print("Division:", a / b)

# Comparison Operators
print("Is a > b?", a > b)

# Logical Operators
print("Logical AND:", a > 1 and b < 1)
print("Logical OR:", a > 1 or b <1)
# Out:
# Addition: 7
# Division: 2.5
# Is a > b? True
# Logical AND: False
# Logical OR: True

# %% [markdown]
# # --- 📌 Try-Except Block ---
#
# The `try-except` block in Python is used to **handle errors gracefully** without crashing the program.
#
# ---
#
# ### 🔹 Why Use Try-Except?
#
# Sometimes your code may encounter errors like:
# - File not found
# - Dividing by zero
# - Invalid input
#
# Using `try-except` prevents the program from stopping and lets you **handle the error** with a custom message or alternative action.
#
# ---

# %%
 result = 10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 result = 10 / 0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("You can't divide by zero!")

# %%
from rdkit import Chem

invalid_smiles = "This is not a SMILES string"

try:
    mol = Chem.MolFromSmiles(invalid_smiles)
    if mol is None:
        print(f"Could not convert '{invalid_smiles}' to a molecule.")
    else:
        print(f"Successfully converted '{invalid_smiles}' to a molecule.")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# ### 🔹 Functions
#
# Functions are **reusable blocks of code** that perform a specific task. They help make your code modular, clean, and easy to maintain.
#
# ---
#
# #### ✅ Why use functions?
# - To avoid code repetition
# - To organize code into logical sections
# - To make debugging and testing easier
# - To reuse code in different parts of a program
#
# ---

# %%
def greet(name):
    """This function greets the person with the given name."""
    print("Hello", name)

greet("Alice")
greet("Bob")

# %%
from rdkit import Chem
from rdkit.Chem.Descriptors import MolWt

def get_molecular_weight(smiles):
  """Calculates the molecular weight of a molecule from its SMILES string."""
  mol = Chem.MolFromSmiles(smiles)
  if mol:
    return MolWt(mol)
  else:
    return None

# Example usage:
aspirin_smiles = "CC(=O)OC1=CC=CC=C1C(=O)O"
mol_weight = get_molecular_weight(aspirin_smiles)

if mol_weight is not None:
  print(f"The molecular weight of Aspirin ({aspirin_smiles}) is: {mol_weight:.2f}")
else:
  print(f"Could not calculate molecular weight for {aspirin_smiles}")

# %% [markdown]
# # --- 📦 Install External Libraries (NumPy, Pandas, Scikit-learn) ---
# Use !pip install in Colab to add external libraries.

# %%
# !pip install numpy pandas scikit-learn -q tensorflow

# %% [markdown]
# # --- 🧮 NumPy Basics ---
#
# NumPy (Numerical Python) is a **powerful Python library** used for **scientific computing**. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on them efficiently.
#
# ---
#
# ### 🔹 Why Use NumPy?
#
# - Faster and more memory-efficient than regular Python lists
# - Useful for numerical computations, linear algebra, statistics
# - Essential for data science and machine learning workflows
# - Forms the foundation for libraries like Pandas, SciPy, Scikit-learn, TensorFlow
#
# ---

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])
print("Array:", arr)
print("Mean:", np.mean(arr))
print("Squared:", np.square(arr))

# %% [markdown]
# # --- 📊 Pandas Basics ---
#
# **Pandas** is a powerful and easy-to-use open-source Python library built for **data manipulation and analysis**. It is especially useful when working with **tabular data** like CSV files, Excel files, or SQL tables.
#
# ---
#
# ### 🔹 Why Use Pandas?
#
# - Provides two main data structures: **Series** (1D) and **DataFrame** (2D)
# - Easy handling of **missing data**
# - Powerful **grouping, merging, filtering, and reshaping** functions
# - Widely used in **data science**, **machine learning**, and **bioinformatics**
#
# ---

# %%
import pandas as pd

# Pandas is used for data manipulation and analysis.
data = {"Name": ["Alice", "Bob"], "Age": [25, 30]}
df = pd.DataFrame(data)
print("DataFrame:")
print(df)

# %%
# Generate chemoinformatics molecule information data
from rdkit import Chem
from rdkit.Chem.Descriptors import MolWt
import pandas as pd

smiles_list = [
    "CCO",                      # Ethanol
    "CC(=O)OC1=CC=CC=C1C(=O)O", # Aspirin
    "C1=CC=CC=C1",               # Benzene
    "CN",                       # Methylamine
    "CC(=O)N",                   # Acetamide
    "C",                        # Methane
    "CO",                       # Methanol
    "CCN"                       # Ethylamine
]

molecule_info_data = []
for smiles in smiles_list:
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        mw = MolWt(mol)
        molecule_info_data.append({"SMILES": smiles, "Molecule": mol, "MolecularWeight": mw})
    else:
        print(f"Could not process SMILES: {smiles}")

df_molecule_info = pd.DataFrame(molecule_info_data)
print("Chemoinformatics Molecule Information Data:")
display(df_molecule_info)

# %% [markdown]
# ## 🤖 Section 2: Introduction to Scikit-learn
# Now that you know Python basics, let's try a simple machine learning example!
#
# We will use the **Iris flower dataset**, which contains measurements of different types of iris flowers. The goal is to classify the flower species based on these measurements.

# %% [markdown]
# ### 🔹 Install scikit-learn
# Run this cell only once to install the library.

# %% [markdown]
# ### 🔹 Import Required Libraries

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### 🔹 Load the Dataset
# The `load_iris()` function gives us features (measurements) and labels (species name) for iris flowers.

# %%
iris = load_iris()
print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
# Out:
# Feature names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names: ['setosa' 'versicolor' 'virginica']

# %%
import pandas as pd

iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target
display(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### 🔹 Split the Dataset
# We divide the data into training (80%) and testing (20%) sets to evaluate model performance.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    iris.data, iris.target, test_size=0.2, random_state=42
)

print("First training sample:", X_train[0])
print("Its label:", y_train[0])

# %% [markdown]
# ![image (1).png](data:image/png;base64,...)
# ### 🔹 Train a Machine Learning Model
# We’ll use the **K-Nearest Neighbors (KNN)** algorithm. It classifies a data point based on how its neighbors are classified.

# %%
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)

# %% [markdown]
# # --- 🌲 Random Forest Classifier ---
#
# ### 🔹 What is a Random Forest?
#
# A **Random Forest** is an **ensemble learning method** that builds multiple decision trees and combines their results to make a more accurate and stable prediction.
#
# - It works for **classification** (categorical labels) and **regression** (continuous values).
# - It reduces **overfitting** by averaging the predictions of many decision trees.
# ![image (3).png](data:image/png;base64,...)
# ---

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# %% [markdown]
# # --- 📈 Support Vector Machine (SVM) Classifier ---
#
# ### 🔹 What is an SVM?
#
# A **Support Vector Machine (SVM)** is a supervised learning algorithm used for **classification** and **regression** tasks. It tries to find the **best decision boundary (hyperplane)** that separates classes in your feature space.
#
# - Works well in **high-dimensional** spaces
# - Particularly effective in cases where the number of dimensions > number of samples
# - Commonly used in **bioinformatics** and **cheminformatics** for molecule classification
#
# ---![image (4).png](data:image/png;base64,...)

# %%
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)

# %% [markdown]
# ### 🔹 Make Predictions and Evaluate
# We use the trained model to make predictions on the test data and compare it to the actual results.

# %%
y_pred = model.predict(X_test)
print("Predictions:", y_pred)
print("Actual:", y_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
y_pred = rf_model.predict(X_test)
print("Predictions:", y_pred)
print("Actual:", y_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
y_pred = svm_model.predict(X_test)
print("Predictions:", y_pred)
print("Actual:", y_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# %% [markdown]
# ### 🔹 Make a Custom Prediction
# We predict the class of a new sample with specific flower measurements.

# %%
sample = [[5.1, 3.5, 1.4, 0.2],[3.3,2.1,1.9,0.9]]
predicted_class = model.predict(sample)
print("Predicted class index:", predicted_class)
print("Predicted flower:", iris.target_names[predicted_class[1]])
print("Predicted flower:", iris.target_names[predicted_class])
# Out:
# Predicted class index: [0 0]
# Predicted flower: setosa
# Predicted flower: ['setosa' 'setosa']

# %% [markdown]
# ## ✅ Congratulations!
# You just:
# - Learned Python basics 🎓
# - Built your first machine learning model 🤖
#
# Feel free to explore more datasets and try changing the model or input values!
